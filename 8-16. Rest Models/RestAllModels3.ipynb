# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('FINAL2_60_large.csv')

# %%
df
# Out:
#        Unnamed: 0  Unnamed: 0.1  Mystery_Data_X  Mystery_Data_Y  Modified  \
# 0               0             0      160.498233     1555.024880      True
# 1               1             1      183.159467      764.843976      True
# 2               2             2      138.609708      129.502065     False
# 3               3             3      122.510822      737.260682      True
# 4               4             4      160.239188     1135.530483      True
# ...           ...           ...             ...             ...       ...
# 74995       74995         74995      129.100253       64.574128     False
# 74996       74996         74996      139.268876     1082.183704      True
# 74997       74997         74997      115.193813        0.000000      True
# 74998       74998         74998      163.254120      127.306753     False
# 74999       74999         74999       99.255115     1922.584834      True
#
#        COPOD    MAD  DeepSVDD   ECOD    GMM   HBOS  LUNAR    PCA    ROD
# ...

# %% [markdown]
# ## 1. COPOD

# %%
count1 = 0
count2 = 0

# %%
l = len(df['Modified'])
l
# Out:
# 75000

# %%
for i in range(0,l):
  if(df['Modified'][i] == True and df['COPOD'][i] == True):
    count1 = count1 + 1
  elif(df['Modified'][i] == False and df['COPOD'][i] == False):
    count1 = count1 + 1
  else:
    count2 = count2 + 1

# %%
accuracy1 = count1/l
accuracy1
# Out:
# 0.7803866666666667

# %%
count1 = 0
count2 = 0

# %%
for i in range(0,l):
  if(df['Modified'][i] == True):
    count1 = count1 + 1
    if(df['COPOD'][i] == True):
      count2 = count2 + 1

# %%
acc1 = count2/count1
acc1
# Out:
# 0.6408564730902149

# %%
count6 = 0
count5 = 0
for i in range(0,l):
  if(df['COPOD'][i] == True):
      count6 = count6 + 1
for i in range(0,l):
  if(df['Modified'][i] == True):
    if(df['COPOD'][i] == True):
      count5 = count5 + 1 
precision = count5/count6
precision
# Out:
# 0.9427616609783845

# %%
count7 = 0
count8 = 0
for i in range(0,l):
  if(df['Modified'][i] == False):
    count8 = count8 + 1
    if(df['COPOD'][i] == False):
      count7 = count7 + 1
sensitivity = count7/count8    
sensitivity
# Out:
# 0.9521132625442432

# %%
f1_score = 2*acc1*precision/(acc1+precision)
f1_score
# Out:
# 0.7630310616196931

# %% [markdown]
# ## 2. GMM

# %%
count3 = 0
count4 = 0

# %%
for i in range(0,l):
  if(df['Modified'][i] == True and df['GMM'][i] == True):
    count3 = count3 + 1
  elif(df['Modified'][i] == False and df['GMM'][i] == False):
    count3 = count3 + 1
  else:
    count4 = count4 + 1

# %%
accuracy2 = count3/l
accuracy2
# Out:
# 0.5517466666666667

# %%
count3 = 0
count4 = 0

# %%
for i in range(0,l):
  if(df['Modified'][i] == True):
    count3 = count3 + 1
    if(df['GMM'][i] == True):
      count4 = count4 + 1

# %%
acc2 = count4/count3
acc2
# Out:
# 0.4336499190410595

# %%
count6 = 0
count5 = 0
for i in range(0,l):
  if(df['GMM'][i] == True):
      count6 = count6 + 1
for i in range(0,l):
  if(df['Modified'][i] == True):
    if(df['GMM'][i] == True):
      count5 = count5 + 1 
precision = count5/count6
precision
# Out:
# 0.6379408418657565

# %%
count7 = 0
count8 = 0
for i in range(0,l):
  if(df['Modified'][i] == False):
    count8 = count8 + 1
    if(df['GMM'][i] == False):
      count7 = count7 + 1
sensitivity = count7/count8    
sensitivity
# Out:
# 0.6970940781059457

# %%
f1_score = 2*acc2*precision/(acc2+precision)
f1_score
# Out:
# 0.5163220970549729

# %% [markdown]
# ## 3. HBOS

# %%
count3 = 0
count4 = 0
for i in range(0,l):
  if(df['Modified'][i] == True and df['HBOS'][i] == True):
    count3 = count3 + 1
  elif(df['Modified'][i] == False and df['HBOS'][i] == False):
    count3 = count3 + 1
  else:
    count4 = count4 + 1  
accuracy3 = count3/l
accuracy3
# Out:
# 0.8081066666666666

# %%
count3 = 0
count4 = 0
for i in range(0,l):
  if(df['Modified'][i] == True):
    count3 = count3 + 1
    if(df['HBOS'][i] == True):
      count4 = count4 + 1
acc3 = count4/count3
acc3
# Out:
# 0.652190724763769

# %%
count6 = 0
count5 = 0
for i in range(0,l):
  if(df['HBOS'][i] == True):
      count6 = count6 + 1
for i in range(0,l):
  if(df['Modified'][i] == True):
    if(df['HBOS'][i] == True):
      count5 = count5 + 1 
precision = count5/count6
precision
# Out:
# 1.0

# %%
count7 = 0
count8 = 0
for i in range(0,l):
  if(df['Modified'][i] == False):
    count8 = count8 + 1
    if(df['HBOS'][i] == False):
      count7 = count7 + 1
sensitivity = count7/count8    
sensitivity
# Out:
# 1.0

# %%
f1_score = 2*acc3*precision/(acc3+precision)
f1_score
# Out:
# 0.789486001813767

# %% [markdown]
# ## 4. PCA

# %%
count3 = 0
count4 = 0
for i in range(0,l):
  if(df['Modified'][i] == True and df['PCA'][i] == True):
    count3 = count3 + 1
  elif(df['Modified'][i] == False and df['PCA'][i] == False):
    count3 = count3 + 1
  else:
    count4 = count4 + 1 
accuracy4 = count3/l
accuracy4
# Out:
# 0.12582666666666667

# %%
count3 = 0
count4 = 0
for i in range(0,l):
  if(df['Modified'][i] == True):
    count3 = count3 + 1
    if(df['PCA'][i] == True):
      count4 = count4 + 1
acc4 = count4/count3
acc4
# Out:
# 0.047657024094347376

# %%
count6 = 0
count5 = 0
for i in range(0,l):
  if(df['PCA'][i] == True):
      count6 = count6 + 1
for i in range(0,l):
  if(df['Modified'][i] == True):
    if(df['PCA'][i] == True):
      count5 = count5 + 1 
precision = count5/count6
precision
# Out:
# 0.0701080773606371

# %%
count7 = 0
count8 = 0
for i in range(0,l):
  if(df['Modified'][i] == False):
    count8 = count8 + 1
    if(df['HBOS'][i] == False):
      count7 = count7 + 1
sensitivity = count7/count8    
sensitivity
# Out:
# 1.0

# %%
f1_score = 2*acc4*precision/(acc4+precision)
f1_score
# Out:
# 0.05674248636827945

# %% [markdown]
# ## 5. ROD

# %%
count3 = 0
count4 = 0
for i in range(0,l):
  if(df['Modified'][i] == True and df['ROD'][i] == True):
    count3 = count3 + 1
  elif(df['Modified'][i] == False and df['ROD'][i] == False):
    count3 = count3 + 1
  else:
    count4 = count4 + 1 
accuracy5 = count3/l
accuracy5
# Out:
# 0.15201333333333333

# %%
count3 = 0
count4 = 0
for i in range(0,l):
  if(df['Modified'][i] == True):
    count3 = count3 + 1
    if(df['ROD'][i] == True):
      count4 = count4 + 1
acc5 = count4/count3
acc5
# Out:
# 0.07138886874984895

# %%
count6 = 0
count5 = 0
for i in range(0,l):
  if(df['ROD'][i] == True):
      count6 = count6 + 1
for i in range(0,l):
  if(df['Modified'][i] == True):
    if(df['ROD'][i] == True):
      count5 = count5 + 1 
precision = count5/count6
precision
# Out:
# 0.10501990898748578

# %%
count7 = 0
count8 = 0
for i in range(0,l):
  if(df['Modified'][i] == False):
    count8 = count8 + 1
    if(df['ROD'][i] == False):
      count7 = count7 + 1
sensitivity = count7/count8    
sensitivity
# Out:
# 0.2512417834091788

# %%
f1_score = 2*acc5*precision/(acc5+precision)
f1_score
# Out:
# 0.08499863323118535

# %% [markdown]
# ## 6. ECOD

# %%
count3 = 0
count4 = 0
for i in range(0,l):
  if(df['Modified'][i] == True and df['ECOD'][i] == True):
    count3 = count3 + 1
  elif(df['Modified'][i] == False and df['ECOD'][i] == False):
    count3 = count3 + 1
  else:
    count4 = count4 + 1 
accuracy6 = count3/l
accuracy6
# Out:
# 0.5732666666666667

# %%
count3 = 0
count4 = 0
for i in range(0,l):
  if(df['Modified'][i] == True):
    count3 = count3 + 1
    if(df['ECOD'][i] == True):
      count4 = count4 + 1
acc6 = count4/count3
acc6
# Out:
# 0.4531525653109065

# %%
count6 = 0
count5 = 0
for i in range(0,l):
  if(df['ECOD'][i] == True):
      count6 = count6 + 1
for i in range(0,l):
  if(df['Modified'][i] == True):
    if(df['ECOD'][i] == True):
      count5 = count5 + 1 
precision = count5/count6
precision
# Out:
# 0.6666311149032992

# %%
count7 = 0
count8 = 0
for i in range(0,l):
  if(df['Modified'][i] == False):
    count8 = count8 + 1
    if(df['ECOD'][i] == False):
      count7 = count7 + 1
sensitivity = count7/count8    
sensitivity
# Out:
# 0.7210969334642039

# %%
f1_score = 2*acc6*precision/(acc6+precision)
f1_score
# Out:
# 0.5395427798638985

# %% [markdown]
# ## 7. DeepSVDD

# %%
count3 = 0
count4 = 0
for i in range(0,l):
  if(df['Modified'][i] == True and df['DeepSVDD'][i] == True):
    count3 = count3 + 1
  elif(df['Modified'][i] == False and df['DeepSVDD'][i] == False):
    count3 = count3 + 1
  else:
    count4 = count4 + 1 
accuracy7 = count3/l
accuracy7
# Out:
# 0.8017733333333333

# %%
count3 = 0
count4 = 0
for i in range(0,l):
  if(df['Modified'][i] == True):
    count3 = count3 + 1
    if(df['DeepSVDD'][i] == True):
      count4 = count4 + 1
acc7 = count4/count3
acc7
# Out:
# 0.7734841344643418

# %%
count6 = 0
count5 = 0
for i in range(0,l):
  if(df['DeepSVDD'][i] == True):
      count6 = count6 + 1
for i in range(0,l):
  if(df['Modified'][i] == True):
    if(df['DeepSVDD'][i] == True):
      count5 = count5 + 1 
precision = count5/count6
precision
# Out:
# 0.8534933333333333

# %%
count7 = 0
count8 = 0
for i in range(0,l):
  if(df['Modified'][i] == False):
    count8 = count8 + 1
    if(df['DeepSVDD'][i] == False):
      count7 = count7 + 1
sensitivity = count7/count8    
sensitivity
# Out:
# 0.8365902263466286

# %%
f1_score = 2*acc7*precision/(acc7+precision)
f1_score
# Out:
# 0.8115214442373763

# %% [markdown]
# ## 8. MAD

# %%
count3 = 0
count4 = 0
for i in range(0,l):
  if(df['Modified'][i] == True and df['MAD'][i] == True):
    count3 = count3 + 1
  elif(df['Modified'][i] == False and df['MAD'][i] == False):
    count3 = count3 + 1
  else:
    count4 = count4 + 1 
accuracy8 = count3/l
accuracy8
# Out:
# 0.59612

# %%
count3 = 0
count4 = 0
for i in range(0,l):
  if(df['Modified'][i] == True):
    count3 = count3 + 1
    if(df['MAD'][i] == True):
      count4 = count4 + 1
acc8 = count4/count3
acc8
# Out:
# 0.2679620097150729

# %%
count6 = 0
count5 = 0
for i in range(0,l):
  if(df['MAD'][i] == True):
      count6 = count6 + 1
for i in range(0,l):
  if(df['Modified'][i] == True):
    if(df['MAD'][i] == True):
      count5 = count5 + 1 
precision = count5/count6
precision
# Out:
# 1.0

# %%
count7 = 0
count8 = 0
for i in range(0,l):
  if(df['Modified'][i] == False):
    count8 = count8 + 1
    if(df['MAD'][i] == False):
      count7 = count7 + 1
sensitivity = count7/count8    
sensitivity
# Out:
# 1.0

# %%
f1_score = 2*acc8*precision/(acc8+precision)
f1_score
# Out:
# 0.42266567556749957

# %% [markdown]
# ## 9. LUNAR

# %%
count3 = 0
count4 = 0
for i in range(0,l):
  if(df['Modified'][i] == True and df['LUNAR'][i] == True):
    count3 = count3 + 1
  elif(df['Modified'][i] == False and df['LUNAR'][i] == False):
    count3 = count3 + 1
  else:
    count4 = count4 + 1 
accuracy9 = count3/l
accuracy9
# Out:
# 0.54136

# %%
count3 = 0
count4 = 0
for i in range(0,l):
  if(df['Modified'][i] == True):
    count3 = count3 + 1
    if(df['LUNAR'][i] == True):
      count4 = count4 + 1
acc9 = count4/count3
acc9
# Out:
# 0.17496797892650862

# %%
count6 = 0
count5 = 0
for i in range(0,l):
  if(df['LUNAR'][i] == True):
      count6 = count6 + 1
for i in range(0,l):
  if(df['Modified'][i] == True):
    if(df['LUNAR'][i] == True):
      count5 = count5 + 1 
precision = count5/count6
precision
# Out:
# 0.9654620616082145

# %%
count7 = 0
count8 = 0
for i in range(0,l):
  if(df['Modified'][i] == False):
    count8 = count8 + 1
    if(df['LUNAR'][i] == False):
      count7 = count7 + 1
sensitivity = count7/count8    
sensitivity
# Out:
# 0.992296481365813

# %%
f1_score = 2*acc9*precision/(acc9+precision)
f1_score
# Out:
# 0.2962478006465077
